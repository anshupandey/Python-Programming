# %% [markdown]
# # Working with Pandas
#     - Work with dataframes & Series
#     - Selection, filtering, manipulation
#     - data import / export with pandas
#     - data wrangling
#
#
# Pandas has two data types:
# - pandas series: 1D data
# - pandas dataframe: 2D data

# %%
import pandas as pd

# %%
# Pandas Series
s = pd.Series([12,56,23,45,78],name='Age')
s
# Out:
# 0    12
# 1    56
# 2    23
# 3    45
# 4    78
# Name: Age, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
# Creating a data frame
data = {'Name':['Anshu','Carlo','Ahmad','Jenny','Jasmine','Jennifer'],
'Gender':['Male','Male','Male','Female','Female','Female'],
'Age':[45,25,22,35,42,32],
'Current City':['DXB','KUL','HXB','DEL','MAA','AUH']}

df = pd.DataFrame(data)
df
# Out:
#        Name  Gender  Age
# 0     Anshu    Male   45
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 5  Jennifer  Female   32

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Selection with dataframes

# %%
df
# Out:
#        Name  Gender  Age
# 0     Anshu    Male   45
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 5  Jennifer  Female   32

# %%
df.head()
# Out:
#       Name  Gender  Age
# 0    Anshu    Male   45
# 1    Carlo    Male   25
# 2    Ahmad    Male   22
# 3    Jenny  Female   35
# 4  Jasmine  Female   42

# %%
df.head(2)
# Out:
#     Name Gender  Age
# 0  Anshu   Male   45
# 1  Carlo   Male   25

# %%
df.tail()
# Out:
#        Name  Gender  Age
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 5  Jennifer  Female   32

# %%
df.tail(3)
# Out:
#        Name  Gender  Age
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 5  Jennifer  Female   32

# %%
# accessing single column
df['Name']
# Out:
# 0       Anshu
# 1       Carlo
# 2       Ahmad
# 3       Jenny
# 4     Jasmine
# 5    Jennifer
# Name: Name, dtype: object

# %%
df.Name # only works if column does not have a whitespace character
# Out:
# 0       Anshu
# 1       Carlo
# 2       Ahmad
# 3       Jenny
# 4     Jasmine
# 5    Jennifer
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df[['Name','Age']] # use two square brackets to access multiple columns from a dataframe
# Out:
#        Name  Age
# 0     Anshu   45
# 1     Carlo   25
# 2     Ahmad   22
# 3     Jenny   35
# 4   Jasmine   42
# 5  Jennifer   32

# %%
type(df[['Name','Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
# accessing data row wise
df[2:5]
# Out:
#       Name  Gender  Age
# 2    Ahmad    Male   22
# 3    Jenny  Female   35
# 4  Jasmine  Female   42

# %%
df['Age'][2:5]
# Out:
# 2    22
# 3    35
# 4    42
# Name: Age, dtype: int64

# %%
# fetch data based on position of cols and rows
df.iloc[2:6,1:3]
# Out:
#    Gender  Age
# 2    Male   22
# 3  Female   35
# 4  Female   42
# 5  Female   32

# %% [markdown]
# #### Filtering

# %%
df
# Out:
#        Name  Gender  Age
# 0     Anshu    Male   45
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 5  Jennifer  Female   32

# %%
# numeric filter
df.Age<35
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# Name: Age, dtype: bool

# %%
df[df.Age<35]
# Out:
#        Name  Gender  Age
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 5  Jennifer  Female   32

# %%
# categoric filter
df[df.Gender=='Male']
# Out:
#     Name Gender  Age
# 0  Anshu   Male   45
# 1  Carlo   Male   25
# 2  Ahmad   Male   22

# %%
# combine multiple conditions
# AND
df[df.Age<35][df.Gender=='Female']
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_5224/324020987.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.Age<35][df.Gender=='Female']
#        Name  Gender  Age
# 5  Jennifer  Female   32

# %%
# AND logic
df[ (df.Age<35) & (df.Gender=='Male')]
# Out:
#     Name Gender  Age
# 1  Carlo   Male   25
# 2  Ahmad   Male   22

# %%
# OR logic
df[ (df.Age<35) | (df.Gender=='Male')]
# Out:
#        Name  Gender  Age
# 0     Anshu    Male   45
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 5  Jennifer  Female   32

# %%
#sort values
df.sort_values(by='Age')
# Out:
#        Name  Gender  Age
# 2     Ahmad    Male   22
# 1     Carlo    Male   25
# 5  Jennifer  Female   32
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 0     Anshu    Male   45

# %%
#sort values
df.sort_values(by='Age').head(1)
# Out:
#     Name Gender  Age
# 2  Ahmad   Male   22

# %%
df[df.Age==df.Age.min()]
# Out:
#     Name Gender  Age
# 2  Ahmad   Male   22

# %% [markdown]
# #### Wrangling and manipulation

# %%
df
# Out:
#        Name  Gender  Age
# 0     Anshu    Male   45
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 5  Jennifer  Female   32

# %%
# Creating a data frame
data = {'Name':['James','John','Jessica'],
'Gender':['Male','Male','Female'],
'Age':[45,25,32]}

df2 = pd.DataFrame(data)
df2
# Out:
#       Name  Gender  Age
# 0    James    Male   45
# 1     John    Male   25
# 2  Jessica  Female   32

# %%
df = pd.concat([df,df2])
df
# Out:
#        Name  Gender  Age
# 0     Anshu    Male   45
# 1     Carlo    Male   25
# 2     Ahmad    Male   22
# 3     Jenny  Female   35
# 4   Jasmine  Female   42
# 5  Jennifer  Female   32
# 0     James    Male   45
# 1      John    Male   25
# 2   Jessica  Female   32

# %%
df['City'] = ['DXB','KUL','AUH','CGK','HGK','HCM','AUH','DXB','MAA']
df
# Out:
#        Name  Gender  Age City
# 0     Anshu    Male   45  DXB
# 1     Carlo    Male   25  KUL
# 2     Ahmad    Male   22  AUH
# 3     Jenny  Female   35  CGK
# 4   Jasmine  Female   42  HGK
# 5  Jennifer  Female   32  HCM
# 0     James    Male   45  AUH
# 1      John    Male   25  DXB
# 2   Jessica  Female   32  MAA

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#        Name  Gender  Age City
# 0     Anshu    Male   45  DXB
# 1     Carlo    Male   25  KUL
# 2     Ahmad    Male   22  AUH
# 3     Jenny  Female   35  CGK
# 4   Jasmine  Female   42  HGK
# 5  Jennifer  Female   32  HCM
# 6     James    Male   45  AUH
# 7      John    Male   25  DXB
# 8   Jessica  Female   32  MAA

# %%
df['Age_cat'] = pd.cut(df['Age'],bins=[0,25,40,90],labels=['Young','Adult','Old'])
df
# Out:
#        Name  Gender  Age City Age_cat
# 0     Anshu    Male   45  DXB     Old
# 1     Carlo    Male   25  KUL   Young
# 2     Ahmad    Male   22  AUH   Young
# 3     Jenny  Female   35  CGK   Adult
# 4   Jasmine  Female   42  HGK     Old
# 5  Jennifer  Female   32  HCM   Adult
# 6     James    Male   45  AUH     Old
# 7      John    Male   25  DXB   Young
# 8   Jessica  Female   32  MAA   Adult

# %%
# drop a column
df.drop(columns=['Age_cat'],inplace=True)

# %%
df
# Out:
#        Name  Gender  Age City
# 0     Anshu    Male   45  DXB
# 1     Carlo    Male   25  KUL
# 2     Ahmad    Male   22  AUH
# 3     Jenny  Female   35  CGK
# 4   Jasmine  Female   42  HGK
# 5  Jennifer  Female   32  HCM
# 6     James    Male   45  AUH
# 7      John    Male   25  DXB
# 8   Jessica  Female   32  MAA

# %%
# drop a column
df.drop(index=[5,6,7],inplace=True)
df
# Out:
#       Name  Gender  Age City
# 0    Anshu    Male   45  DXB
# 1    Carlo    Male   25  KUL
# 2    Ahmad    Male   22  AUH
# 3    Jenny  Female   35  CGK
# 4  Jasmine  Female   42  HGK
# 8  Jessica  Female   32  MAA

# %% [markdown]
# #### Statistical Analysis

# %%
df.describe(include='all')
# Out:
#          Name Gender        Age City
# count       6      6   6.000000    6
# unique      6      2        NaN    6
# top     Anshu   Male        NaN  DXB
# freq        1      3        NaN    1
# mean      NaN    NaN  33.500000  NaN
# std       NaN    NaN   9.093954  NaN
# min       NaN    NaN  22.000000  NaN
# 25%       NaN    NaN  26.750000  NaN
# 50%       NaN    NaN  33.500000  NaN
# 75%       NaN    NaN  40.250000  NaN
# max       NaN    NaN  45.000000  NaN

# %%
df.Age.min()
# Out:
# 22

# %%
df.Age.max()
# Out:
# 45

# %%
df.Age.mean()
# Out:
# 33.5

# %%
df.Age.median()
# Out:
# 33.5

# %%
df.Gender.mode()
# Out:
# 0    Female
# 1      Male
# dtype: object

# %%
df.Age.var()
# Out:
# 82.7

# %%
df.Age.std()
# Out:
# 9.093954035511725

# %%
df.Age.skew()
# Out:
# 0.0

# %% [markdown]
# ### Data Import / Export with Pandas

# %%
# loading data from a CSV file
df = pd.read_csv(r"D:\AI\data\datasets-1\Bank_churn_modelling.csv")
df.shape
# Out:
# (10000, 14)

# %%
df.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0      0.00              1          1               1
# 1     1.0  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
# loading data from an Excel file
df = pd.read_excel(r"D:\AI\data\datasets-1\Bank_churn_modelling.xlsx")
df.shape
# Out:
# (10000, 14)

# %%
df.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
# loading data from a json file
df = pd.read_json(r"D:\AI\data\datasets-1\server-metrics.json")
df.shape
# Out:
# (20, 6)

# %%
df.head()
# Out:
#    id          dates  Accepted  Rejected    App     Server
# 0   0  1525046400000       218       182  App_4  Server_02
# 1   1  1525132800000      2592       182  App_3  Server_02
# 2   2  1525219200000       509       439  App_4   Server_0
# 3   3  1525305600000      2439        53  App_5  Server_01
# 4   4  1525392000000       824       444  App_5   Server_0

# %%
url = "https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory"
df_list = pd.read_html(url)
len(df_list)
# Out:
# 70

# %%
df_list[0]
# Out:
#                                     COVID-19 pandemic  \
# 0   Confirmed deaths per 100,000 population,[1][no...
# 1                                             Disease
# 2                                        Virus strain
# 3                                              Source
# 4                                            Location
# 5                                      First outbreak
# 6                                          Index case
# 7                                                Date
# 8                                     Confirmed cases
# 9                                              Deaths
# 10                                       Vaccinations
#
#                                   COVID-19 pandemic.1
# 0   Confirmed deaths per 100,000 population,[1][no...
# 1                                            COVID-19
# 2                                          SARS-CoV-2
# 3         Probably bats, possibly via pangolins[2][3]
# 4                                           Worldwide
# 5                                            China[4]
# 6   Wuhan, Hubei, China.mw-parser-output .geo-defa...
# 7   17 November 2019[4] – present(2 years, 10 mont...
# 8                                      612,314,658[5]
# 9                                        6,527,372[5]
# 10  5,370,041,428[5] (total vaccinated)4,939,888,6...

# %%
# get only those tables which has more than 10 rows
final_list = []
for df in df_list:
    if df.shape[0]>10:
        final_list.append(df)

# %%
len(final_list)
# Out:
# 18

# %%
final_list[4]
# Out:
#                           Region[29]  Total cases  Total deaths  \
# 0                     European Union    163770077       1138276
# 1                      North America     98420934       1090029
# 2                       Other Europe     55795334        491883
# 3                      South America     63162506       1300158
# 4            Russia and Central Asia     23934534        426857
# 5                    Central America     10976906        378719
# 6                        Middle East     22266626        236911
# 7   Oceania and islands in East Asia     47860321        292366
# 8                          Caribbean      2573339         25811
# 9                         South Asia     50123528        617393
# 10                      North Africa      3717201         83807
# 11                         East Asia     50715909        182084
# 12                Sub-Saharan Africa      8516338        171848
# 13               Totals (or average)    601833553       6436142
#
#     Cases per million  Deaths per million  Current weekly cases  \
# 0              366114                2545                648555
# 1              266863                2956                523615
# 2              238808                2105                130330
# 3              146932                3025                118462
# 4              101077                1803                339111
# 5               61095                2108                 37351
# 6               85315                 908                 28133
# 7               82894                 506               1031665
# 8               59437                 596                  4997
# 9               27001                 333                 45511
# 10              18332                 413                  1208
# 11              28409                 102                573700
# 12               7492                 151                  7070
# 13              77566                 830               3489708
#
#     Current weekly deaths  Population millions  Vaccinated %[30]
# 0                    2543                  447              75.0
# 1                    2936                  369              74.6
# 2                     812                  234              61.0
# 3                    1168                  430              81.2
# 4                     668                  237              54.4
# 5                     292                  180              67.3
# 6                     253                  261              51.7
# 7                    2590                  577              71.7
# 8                      55                   43              46.1
# 9                     211                 1856              68.5
# 10                      8                  203              41.2
# 11                    610                 1785              86.9
# 12                     63                 1137              20.4
# 13                  12209                 7759              65.4

# %%
df = final_list[4]

# %%
# export a dataframe to a file/source
df.to_excel(r"D:\ai\Python-Programming\heretech\coivd_world_data.xlsx")

# %% [markdown]
# ### Accessing/extracting data from HTML

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/FIFA"
df_collection = pd.read_html(url) # read_html returns a list of dataframes
len(df_collection)
# Out:
# 31

# %%
df_collection[7]
# Out:
#                                                     0                       1  \
# 0                                         Competition                     NaN
# 1                                      National teams          National teams
# 2                                      FIFA World Cup                     NaN
# 3            Men's Olympic Football Tournament (U-23)                     NaN
# 4                                 FIFA U-20 World Cup                     NaN
# 5                                 FIFA U-17 World Cup                     NaN
# 6                               FIFA Futsal World Cup                     NaN
# 7        Men's Youth Olympic Futsal Tournament (U-20)                     NaN
# 8          FIFA Beach Soccer World Cup (see the BSWW)                     NaN
# 9   FIFA Arab Cup (senior teams of the UAFA (Arab ...                     NaN
# 10                             National teams (women)  National teams (women)
# 11                             FIFA Women's World Cup                     NaN
# 12                Women's Olympic Football Tournament                     NaN
# 13                        FIFA U-20 Women's World Cup                     NaN
# 14                        FIFA U-17 Women's World Cup                     NaN
# 15     Women's Youth Olympic Futsal Tournament (U-20)                     NaN
# 16                                          Club team               Club team
# 17                                FIFA Club World Cup                     NaN
# 18                          Blue Stars/FIFA Youth Cup                     NaN
# 19                                 Club teams (women)      Club teams (women)
# 20                          Blue Stars/FIFA Youth Cup                     NaN
#
#                          2                       3                       4  \
# 0                     Year               Champions                   Title
# 1           National teams          National teams          National teams
# 2             2018 (Final)                  France                     2nd
# 3             2020 (Final)                  Brazil                     2nd
# 4             2019 (Final)                 Ukraine                     1st
# 5             2019 (Final)                  Brazil                     4th
# 6             2021 (Final)                Portugal                     1st
# 7             2018 (Final)                  Brazil                     1st
# 8             2021 (Final)                  Russia                     3rd
# 9             2021 (Final)                 Algeria                     1st
# 10  National teams (women)  National teams (women)  National teams (women)
# 11            2019 (Final)           United States                     4th
# 12            2021 (Final)                  Canada                     1st
# 13            2022 (Final)                   Spain                     1st
# 14            2018 (Final)                   Spain                     1st
# 15            2018 (Final)                Portugal                     1st
# 16               Club team               Club team               Club team
# 17            2021 (Final)                 Chelsea                     1st
# 18                2022[56]                   Basel                     3rd
# 19      Club teams (women)      Club teams (women)      Club teams (women)
# 20                2022[56]                  Zürich                     1st
#
#                          5                       6                       7  \
# 0               Runners-up                     NaN        Next edition[55]
# 1           National teams          National teams          National teams
# 2                  Croatia                     NaN            2022 (Final)
# 3                    Spain                     NaN            2024 (Final)
# 4              South Korea                     NaN            2023 (Final)
# 5                   Mexico                     NaN            2023 (Final)
# 6                Argentina                     NaN            2024 (Final)
# 7                   Russia                     NaN                    2026
# 8                    Japan                     NaN            2023 (Final)
# 9                  Tunisia                     NaN                     TBD
# 10  National teams (women)  National teams (women)  National teams (women)
# 11             Netherlands                     NaN            2023 (Final)
# 12                  Sweden                     NaN            2024 (Final)
# 13                   Japan                     NaN            2024 (Final)
# 14                  Mexico                     NaN            2022 (Final)
# 15                   Japan                     NaN                    2026
# 16               Club team               Club team               Club team
# 17               Palmeiras                     NaN             TBD (China)
# 18                   Mainz                     NaN                    2023
# 19      Club teams (women)      Club teams (women)      Club teams (women)
# 20                    Lyon                     NaN                    2023
#
#                          8                   9
# 0                      NaN                 NaN
# 1           National teams                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# 5                      NaN                 NaN
# 6                      NaN                 NaN
# 7                      NaN                 NaN
# 8                      NaN                 NaN
# 9                      NaN                 NaN
# 10  National teams (women)                 NaN
# 11                     NaN                 NaN
# 12                     NaN                 NaN
# 13                     NaN                 NaN
# 14                     NaN                 NaN
# 15                     NaN                 NaN
# 16               Club team                 NaN
# 17                     NaN                 NaN
# 18                     NaN                 NaN
# 19      Club teams (women)  Club teams (women)
# 20                     NaN                 NaN

# %%
mydf = df_collection[7]
mydf
# Out:
#                                                     0                       1  \
# 0                                         Competition                     NaN
# 1                                      National teams          National teams
# 2                                      FIFA World Cup                     NaN
# 3            Men's Olympic Football Tournament (U-23)                     NaN
# 4                                 FIFA U-20 World Cup                     NaN
# 5                                 FIFA U-17 World Cup                     NaN
# 6                               FIFA Futsal World Cup                     NaN
# 7        Men's Youth Olympic Futsal Tournament (U-20)                     NaN
# 8          FIFA Beach Soccer World Cup (see the BSWW)                     NaN
# 9   FIFA Arab Cup (senior teams of the UAFA (Arab ...                     NaN
# 10                             National teams (women)  National teams (women)
# 11                             FIFA Women's World Cup                     NaN
# 12                Women's Olympic Football Tournament                     NaN
# 13                        FIFA U-20 Women's World Cup                     NaN
# 14                        FIFA U-17 Women's World Cup                     NaN
# 15     Women's Youth Olympic Futsal Tournament (U-20)                     NaN
# 16                                          Club team               Club team
# 17                                FIFA Club World Cup                     NaN
# 18                          Blue Stars/FIFA Youth Cup                     NaN
# 19                                 Club teams (women)      Club teams (women)
# 20                          Blue Stars/FIFA Youth Cup                     NaN
#
#                          2                       3                       4  \
# 0                     Year               Champions                   Title
# 1           National teams          National teams          National teams
# 2             2018 (Final)                  France                     2nd
# 3             2020 (Final)                  Brazil                     2nd
# 4             2019 (Final)                 Ukraine                     1st
# 5             2019 (Final)                  Brazil                     4th
# 6             2021 (Final)                Portugal                     1st
# 7             2018 (Final)                  Brazil                     1st
# 8             2021 (Final)                  Russia                     3rd
# 9             2021 (Final)                 Algeria                     1st
# 10  National teams (women)  National teams (women)  National teams (women)
# 11            2019 (Final)           United States                     4th
# 12            2021 (Final)                  Canada                     1st
# 13            2022 (Final)                   Spain                     1st
# 14            2018 (Final)                   Spain                     1st
# 15            2018 (Final)                Portugal                     1st
# 16               Club team               Club team               Club team
# 17            2021 (Final)                 Chelsea                     1st
# 18                2022[56]                   Basel                     3rd
# 19      Club teams (women)      Club teams (women)      Club teams (women)
# 20                2022[56]                  Zürich                     1st
#
#                          5                       6                       7  \
# 0               Runners-up                     NaN        Next edition[55]
# 1           National teams          National teams          National teams
# 2                  Croatia                     NaN            2022 (Final)
# 3                    Spain                     NaN            2024 (Final)
# 4              South Korea                     NaN            2023 (Final)
# 5                   Mexico                     NaN            2023 (Final)
# 6                Argentina                     NaN            2024 (Final)
# 7                   Russia                     NaN                    2026
# 8                    Japan                     NaN            2023 (Final)
# 9                  Tunisia                     NaN                     TBD
# 10  National teams (women)  National teams (women)  National teams (women)
# 11             Netherlands                     NaN            2023 (Final)
# 12                  Sweden                     NaN            2024 (Final)
# 13                   Japan                     NaN            2024 (Final)
# 14                  Mexico                     NaN            2022 (Final)
# 15                   Japan                     NaN                    2026
# 16               Club team               Club team               Club team
# 17               Palmeiras                     NaN             TBD (China)
# 18                   Mainz                     NaN                    2023
# 19      Club teams (women)      Club teams (women)      Club teams (women)
# 20                    Lyon                     NaN                    2023
#
#                          8                   9
# 0                      NaN                 NaN
# 1           National teams                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# 5                      NaN                 NaN
# 6                      NaN                 NaN
# 7                      NaN                 NaN
# 8                      NaN                 NaN
# 9                      NaN                 NaN
# 10  National teams (women)                 NaN
# 11                     NaN                 NaN
# 12                     NaN                 NaN
# 13                     NaN                 NaN
# 14                     NaN                 NaN
# 15                     NaN                 NaN
# 16               Club team                 NaN
# 17                     NaN                 NaN
# 18                     NaN                 NaN
# 19      Club teams (women)  Club teams (women)
# 20                     NaN                 NaN

# %%
mydf.to_excel("D:\ai\fifadata.xlsx")

# %%
# check the current working direcrory
import os
os.getcwd()
# Out:
# 'd:\\AI\\Python-Programming\\HereTech'

# %%
m = "hello from python \new world"
print(m)
# Out:
# hello from python
# ew world

# %%
m = r"hello from python \new world"
print(m)
# Out:
# hello from python \new world

# %% [markdown]
# ### Data Aggregation with Pandas

# %%
df1 = pd.read_csv(r"D:\AI\data\datasets-1\regiment.csv",index_col='index')
df1.shape
# Out:
# (12, 5)

# %%
df1
# Out:
#          regiment company      name  preTestScore  postTestScore
# index
# 0      Nighthawks     1st    Miller             4             25
# 1      Nighthawks     1st  Jacobson            24             94
# 2      Nighthawks     2nd       Ali            31             57
# 3      Nighthawks     2nd    Milner             2             62
# 4        Dragoons     1st     Cooze             3             70
# 5        Dragoons     1st     Jacon             4             25
# 6        Dragoons     2nd    Ryaner            24             94
# 7        Dragoons     2nd      Sone            31             57
# 8          Scouts     1st     Sloan             2             62
# 9          Scouts     1st     Piger             3             70
# 10         Scouts     2nd     Riani             2             62
# 11         Scouts     2nd      Alii             3             70

# %%
df2 = pd.read_csv(r"D:\AI\data\datasets-1\regiment2.csv")
df2
# Out:
#         name date_of_birth
# 0     Miller    12-05-1985
# 1   Jacobson    30-05-1987
# 2        Ali    04-06-1990
# 3     Milner    01-08-1989
# 4      Cooze    12-09-1985
# 5      Jacon    30-05-1986
# 6     Ryaner    04-02-1990
# 7       Sone    01-01-1989
# 8      Sloan    12-05-1995
# 9      Piger    30-05-1986
# 10     Riani    09-03-1990
# 11      Alii    01-06-1979

# %%
#create a dataframe by merging data from regiment.csv and regiment2.csv using name column
df = pd.merge(left=df1,right=df2,on='name',how='inner')
df
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth
# 0   Nighthawks     1st    Miller             4             25    12-05-1985
# 1   Nighthawks     1st  Jacobson            24             94    30-05-1987
# 2   Nighthawks     2nd       Ali            31             57    04-06-1990
# 3   Nighthawks     2nd    Milner             2             62    01-08-1989
# 4     Dragoons     1st     Cooze             3             70    12-09-1985
# 5     Dragoons     1st     Jacon             4             25    30-05-1986
# 6     Dragoons     2nd    Ryaner            24             94    04-02-1990
# 7     Dragoons     2nd      Sone            31             57    01-01-1989
# 8       Scouts     1st     Sloan             2             62    12-05-1995
# 9       Scouts     1st     Piger             3             70    30-05-1986
# 10      Scouts     2nd     Riani             2             62    09-03-1990
# 11      Scouts     2nd      Alii             3             70    01-06-1979

# %%
df1.drop(index=[4,5,9,11],inplace=True)
df1
# Out:
#          regiment company      name  preTestScore  postTestScore
# index
# 0      Nighthawks     1st    Miller             4             25
# 1      Nighthawks     1st  Jacobson            24             94
# 2      Nighthawks     2nd       Ali            31             57
# 3      Nighthawks     2nd    Milner             2             62
# 6        Dragoons     2nd    Ryaner            24             94
# 7        Dragoons     2nd      Sone            31             57
# 8          Scouts     1st     Sloan             2             62
# 10         Scouts     2nd     Riani             2             62

# %%
df2.drop(index=[1,7],inplace=True)
df2
# Out:
#       name date_of_birth
# 0   Miller    12-05-1985
# 2      Ali    04-06-1990
# 3   Milner    01-08-1989
# 4    Cooze    12-09-1985
# 5    Jacon    30-05-1986
# 6   Ryaner    04-02-1990
# 8    Sloan    12-05-1995
# 9    Piger    30-05-1986
# 10   Riani    09-03-1990
# 11    Alii    01-06-1979

# %%
#inner join
mydf = pd.merge(left=df1,right=df2,on='name',how='inner')
mydf
# Out:
#      regiment company    name  preTestScore  postTestScore date_of_birth
# 0  Nighthawks     1st  Miller             4             25    12-05-1985
# 1  Nighthawks     2nd     Ali            31             57    04-06-1990
# 2  Nighthawks     2nd  Milner             2             62    01-08-1989
# 3    Dragoons     2nd  Ryaner            24             94    04-02-1990
# 4      Scouts     1st   Sloan             2             62    12-05-1995
# 5      Scouts     2nd   Riani             2             62    09-03-1990

# %%
#left join
mydf = pd.merge(left=df1,right=df2,on='name',how='left')
mydf
# Out:
#      regiment company      name  preTestScore  postTestScore date_of_birth
# 0  Nighthawks     1st    Miller             4             25    12-05-1985
# 1  Nighthawks     1st  Jacobson            24             94           NaN
# 2  Nighthawks     2nd       Ali            31             57    04-06-1990
# 3  Nighthawks     2nd    Milner             2             62    01-08-1989
# 4    Dragoons     2nd    Ryaner            24             94    04-02-1990
# 5    Dragoons     2nd      Sone            31             57           NaN
# 6      Scouts     1st     Sloan             2             62    12-05-1995
# 7      Scouts     2nd     Riani             2             62    09-03-1990

# %%
#right join
mydf = pd.merge(left=df1,right=df2,on='name',how='right')
mydf
# Out:
#      regiment company    name  preTestScore  postTestScore date_of_birth
# 0  Nighthawks     1st  Miller           4.0           25.0    12-05-1985
# 1  Nighthawks     2nd     Ali          31.0           57.0    04-06-1990
# 2  Nighthawks     2nd  Milner           2.0           62.0    01-08-1989
# 3         NaN     NaN   Cooze           NaN            NaN    12-09-1985
# 4         NaN     NaN   Jacon           NaN            NaN    30-05-1986
# 5    Dragoons     2nd  Ryaner          24.0           94.0    04-02-1990
# 6      Scouts     1st   Sloan           2.0           62.0    12-05-1995
# 7         NaN     NaN   Piger           NaN            NaN    30-05-1986
# 8      Scouts     2nd   Riani           2.0           62.0    09-03-1990
# 9         NaN     NaN    Alii           NaN            NaN    01-06-1979

# %%
#outer join
mydf = pd.merge(left=df1,right=df2,on='name',how='outer')
mydf
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth
# 0   Nighthawks     1st    Miller           4.0           25.0    12-05-1985
# 1   Nighthawks     1st  Jacobson          24.0           94.0           NaN
# 2   Nighthawks     2nd       Ali          31.0           57.0    04-06-1990
# 3   Nighthawks     2nd    Milner           2.0           62.0    01-08-1989
# 4     Dragoons     2nd    Ryaner          24.0           94.0    04-02-1990
# 5     Dragoons     2nd      Sone          31.0           57.0           NaN
# 6       Scouts     1st     Sloan           2.0           62.0    12-05-1995
# 7       Scouts     2nd     Riani           2.0           62.0    09-03-1990
# 8          NaN     NaN     Cooze           NaN            NaN    12-09-1985
# 9          NaN     NaN     Jacon           NaN            NaN    30-05-1986
# 10         NaN     NaN     Piger           NaN            NaN    30-05-1986
# 11         NaN     NaN      Alii           NaN            NaN    01-06-1979

# %%
df1 = pd.read_csv(r"D:\AI\data\datasets-1\regiment.csv",index_col='index')
df2 = pd.read_csv(r"D:\AI\data\datasets-1\regiment2.csv")
df = pd.merge(left=df1,right=df2,on='name',how='inner')
df
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth
# 0   Nighthawks     1st    Miller             4             25    12-05-1985
# 1   Nighthawks     1st  Jacobson            24             94    30-05-1987
# 2   Nighthawks     2nd       Ali            31             57    04-06-1990
# 3   Nighthawks     2nd    Milner             2             62    01-08-1989
# 4     Dragoons     1st     Cooze             3             70    12-09-1985
# 5     Dragoons     1st     Jacon             4             25    30-05-1986
# 6     Dragoons     2nd    Ryaner            24             94    04-02-1990
# 7     Dragoons     2nd      Sone            31             57    01-01-1989
# 8       Scouts     1st     Sloan             2             62    12-05-1995
# 9       Scouts     1st     Piger             3             70    30-05-1986
# 10      Scouts     2nd     Riani             2             62    09-03-1990
# 11      Scouts     2nd      Alii             3             70    01-06-1979

# %%
# which regiment is the best/most efficient regiment after the training?
df.postTestScore.mean()
# Out:
# 62.333333333333336

# %%
df.groupby(by=['regiment'])['postTestScore'].mean()
# Out:
# regiment
# Dragoons      61.5
# Nighthawks    59.5
# Scouts        66.0
# Name: postTestScore, dtype: float64

# %%
# which company of which regiment is most efficient company?
df.groupby(by=['regiment','company'])['postTestScore'].mean()
# Out:
# regiment    company
# Dragoons    1st        47.5
#             2nd        75.5
# Nighthawks  1st        59.5
#             2nd        59.5
# Scouts      1st        66.0
#             2nd        66.0
# Name: postTestScore, dtype: float64

# %%
# create a column representing improvement made by individual soldiers during the training
df['improvement'] = df['postTestScore'] - df['preTestScore']
df
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth  \
# 0   Nighthawks     1st    Miller             4             25    12-05-1985
# 1   Nighthawks     1st  Jacobson            24             94    30-05-1987
# 2   Nighthawks     2nd       Ali            31             57    04-06-1990
# 3   Nighthawks     2nd    Milner             2             62    01-08-1989
# 4     Dragoons     1st     Cooze             3             70    12-09-1985
# 5     Dragoons     1st     Jacon             4             25    30-05-1986
# 6     Dragoons     2nd    Ryaner            24             94    04-02-1990
# 7     Dragoons     2nd      Sone            31             57    01-01-1989
# 8       Scouts     1st     Sloan             2             62    12-05-1995
# 9       Scouts     1st     Piger             3             70    30-05-1986
# 10      Scouts     2nd     Riani             2             62    09-03-1990
# 11      Scouts     2nd      Alii             3             70    01-06-1979
#
#     improvement
# 0            21
# 1            70
# 2            26
# 3            60
# 4            67
# 5            21
# 6            70
# 7            26
# 8            60
# 9            67
# 10           60
# 11           67

# %%
# which regiment soldiers made most improvement and can be called as fastest learners ?
df.groupby(by=['regiment'])['improvement'].mean()
# Out:
# regiment
# Dragoons      46.00
# Nighthawks    44.25
# Scouts        63.50
# Name: improvement, dtype: float64

# %%
df
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth  \
# 0   Nighthawks     1st    Miller             4             25    12-05-1985
# 1   Nighthawks     1st  Jacobson            24             94    30-05-1987
# 2   Nighthawks     2nd       Ali            31             57    04-06-1990
# 3   Nighthawks     2nd    Milner             2             62    01-08-1989
# 4     Dragoons     1st     Cooze             3             70    12-09-1985
# 5     Dragoons     1st     Jacon             4             25    30-05-1986
# 6     Dragoons     2nd    Ryaner            24             94    04-02-1990
# 7     Dragoons     2nd      Sone            31             57    01-01-1989
# 8       Scouts     1st     Sloan             2             62    12-05-1995
# 9       Scouts     1st     Piger             3             70    30-05-1986
# 10      Scouts     2nd     Riani             2             62    09-03-1990
# 11      Scouts     2nd      Alii             3             70    01-06-1979
#
#     improvement
# 0            21
# 1            70
# 2            26
# 3            60
# 4            67
# 5            21
# 6            70
# 7            26
# 8            60
# 9            67
# 10           60
# 11           67

# %%
x = "Anshu"
x.upper()
# Out:
# 'ANSHU'

# %%
def change_name(x):
    return x.upper()

change_name("Jacob")
# Out:
# 'JACOB'

# %%
df['name'] = df['name'].apply(change_name)
df
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth  \
# 0   Nighthawks     1st    MILLER             4             25    12-05-1985
# 1   Nighthawks     1st  JACOBSON            24             94    30-05-1987
# 2   Nighthawks     2nd       ALI            31             57    04-06-1990
# 3   Nighthawks     2nd    MILNER             2             62    01-08-1989
# 4     Dragoons     1st     COOZE             3             70    12-09-1985
# 5     Dragoons     1st     JACON             4             25    30-05-1986
# 6     Dragoons     2nd    RYANER            24             94    04-02-1990
# 7     Dragoons     2nd      SONE            31             57    01-01-1989
# 8       Scouts     1st     SLOAN             2             62    12-05-1995
# 9       Scouts     1st     PIGER             3             70    30-05-1986
# 10      Scouts     2nd     RIANI             2             62    09-03-1990
# 11      Scouts     2nd      ALII             3             70    01-06-1979
#
#     improvement
# 0            21
# 1            70
# 2            26
# 3            60
# 4            67
# 5            21
# 6            70
# 7            26
# 8            60
# 9            67
# 10           60
# 11           67

# %%
df
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth  \
# 0   Nighthawks     1st    MILLER             4             25    12-05-1985
# 1   Nighthawks     1st  JACOBSON            24             94    30-05-1987
# 2   Nighthawks     2nd       ALI            31             57    04-06-1990
# 3   Nighthawks     2nd    MILNER             2             62    01-08-1989
# 4     Dragoons     1st     COOZE             3             70    12-09-1985
# 5     Dragoons     1st     JACON             4             25    30-05-1986
# 6     Dragoons     2nd    RYANER            24             94    04-02-1990
# 7     Dragoons     2nd      SONE            31             57    01-01-1989
# 8       Scouts     1st     SLOAN             2             62    12-05-1995
# 9       Scouts     1st     PIGER             3             70    30-05-1986
# 10      Scouts     2nd     RIANI             2             62    09-03-1990
# 11      Scouts     2nd      ALII             3             70    01-06-1979
#
#     improvement
# 0            21
# 1            70
# 2            26
# 3            60
# 4            67
# 5            21
# 6            70
# 7            26
# 8            60
# 9            67
# 10           60
# 11           67

# %%
df.dtypes
# Out:
# regiment         object
# company          object
# name             object
# preTestScore      int64
# postTestScore     int64
# date_of_birth    object
# improvement       int64
# dtype: object

# %%
# standardize date of birth col to pandas datetime format
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'])
df.dtypes
# Out:
# regiment                 object
# company                  object
# name                     object
# preTestScore              int64
# postTestScore             int64
# date_of_birth    datetime64[ns]
# improvement               int64
# dtype: object

# %%
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2022, 9, 22, 9, 20, 10, 411211)

# %%
def dob2age(dob):
    days = (today-dob).days
    years = days/365
    return round(years)

# %%
dob2age(pd.to_datetime("12-12-1988"))
# Out:
# 34

# %%
(today - pd.to_datetime("12-12-1988")).seconds/3600
# Out:
# 9.33611111111111

# %%
df['age'] = df['date_of_birth'].apply(dob2age)
df
# Out:
#       regiment company      name  preTestScore  postTestScore date_of_birth  \
# 0   Nighthawks     1st    MILLER             4             25    1985-12-05
# 1   Nighthawks     1st  JACOBSON            24             94    1987-05-30
# 2   Nighthawks     2nd       ALI            31             57    1990-04-06
# 3   Nighthawks     2nd    MILNER             2             62    1989-01-08
# 4     Dragoons     1st     COOZE             3             70    1985-12-09
# 5     Dragoons     1st     JACON             4             25    1986-05-30
# 6     Dragoons     2nd    RYANER            24             94    1990-04-02
# 7     Dragoons     2nd      SONE            31             57    1989-01-01
# 8       Scouts     1st     SLOAN             2             62    1995-12-05
# 9       Scouts     1st     PIGER             3             70    1986-05-30
# 10      Scouts     2nd     RIANI             2             62    1990-09-03
# 11      Scouts     2nd      ALII             3             70    1979-01-06
#
#     improvement  age
# 0            21   37
# 1            70   35
# 2            26   32
# 3            60   34
# 4            67   37
# 5            21   36
# 6            70   32
# 7            26   34
# 8            60   27
# 9            67   36
# 10           60   32
# 11           67   44

# %%
# which regiment has youngest soldiers
df.groupby(by=['regiment'])['age'].mean()
# Out:
# regiment
# Dragoons      34.75
# Nighthawks    34.50
# Scouts        34.75
# Name: age, dtype: float64

# %%
# which company of which regiment has youngest soldiers
df.groupby(by=['regiment','company'])['age'].mean()
# Out:
# regiment    company
# Dragoons    1st        36.5
#             2nd        33.0
# Nighthawks  1st        36.0
#             2nd        33.0
# Scouts      1st        31.5
#             2nd        38.0
# Name: age, dtype: float64

# %%
# which company has best combination low age and high postTestScore
df.groupby(by=['regiment','company'])[['postTestScore','age']].mean()
# Out:
#                     postTestScore   age
# regiment   company
# Dragoons   1st               47.5  36.5
#            2nd               75.5  33.0
# Nighthawks 1st               59.5  36.0
#            2nd               59.5  33.0
# Scouts     1st               66.0  31.5
#            2nd               66.0  38.0

# %%
df.groupby(by=['regiment','company'])[['postTestScore','age']].mean().sort_values(by=['age','postTestScore']).head(1)
# Out:
#                   postTestScore   age
# regiment company
# Scouts   1st               66.0  31.5
